# %%
from sklearn.datasets import load_iris
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
iris_bunch = load_iris()
iris_df = pd.DataFrame(iris_bunch.data,columns =iris_bunch.feature_names)
iris_df["class"] = iris_bunch.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 0        0
# ...

# %%
x= iris_df.drop(columns="class")
y = iris_df["class"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state =21)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbd_mod = GradientBoostingClassifier(n_estimators=20,learning_rate=0.3)
gbd_mod.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.3, n_estimators=20)

# %%
y_pred_test = gbd_mod.predict(x_test)
y_pred_train = gbd_mod.predict(x_train)

# %%
print("accuracy score for the test data set is:")
print(accuracy_score(y_test,y_pred_test))
# Out:
# accuracy score for the test data set is:
# 0.9333333333333333

# %%
print("accuracy score for the train data set is:")
print(accuracy_score(y_train,y_pred_train))
# Out:
# accuracy score for the train data set is:
# 1.0

# %%
print("classifier report  for the train data set is:")
print(classification_report(y_train,y_pred_train))
# Out:
# classifier report  for the train data set is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        39
#            1       1.00      1.00      1.00        38
#            2       1.00      1.00      1.00        43
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
print("classifier report  for the test data set is:")
print(classification_report(y_test,y_pred_test))
# Out:
# classifier report  for the test data set is:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.83      0.91        12
#            2       0.78      1.00      0.88         7
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.94      0.93        30
# weighted avg       0.95      0.93      0.93        30

# %% [markdown]
# ### XG BOST CLASSIFIER

# %%
from xgboost.sklearn import XGBClassifier

# %%
! pip install xgboost
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 640.0 kB/s eta 0:02:36
#    ---------------------------------------- 0.0/99.8 MB 640.0 kB/s eta 0:02:36
#    ---------------------------------------- 0.1/99.8 MB 491.5 kB/s eta 0:03:23
#    ---------------------------------------- 0.1/99.8 MB 655.4 kB/s eta 0:02:33
#    ---------------------------------------- 0.1/99.8 MB 708.1 kB/s eta 0:02:21
#    ---------------------------------------- 0.2/99.8 MB 706.2 kB/s eta 0:02:22
#    ---------------------------------------- 0.2/99.8 MB 689.9 kB/s eta 0:02:25
#    ---------------------------------------- 0.2/99.8 MB 762.6 kB/s eta 0:02:11
#    ---------------------------------------- 0.2/99.8 MB 625.8 kB/s eta 0:02:40
# ...

# %%
xgboost_model = XGBClassifier(n_estimators=20,objective="multi:softmax",num_class= 3)
